# %%
import os
import spacy
import numpy as np
import docx2txt
import collections

homeDir = '/home/ubuntu/writerAuthentification/dataset-1/'




def convertToPOS(text):
#Converts text to POS using spacy. This particular method ignores punctuation and spaces

	posText = ""
	nlp = spacy.load("en_core_web_sm")
	doc = nlp(str(text))

	for token in doc:

		if not(token.pos_ == 'SPACE' or token.pos_ == 'PUNCT'):

			posText = posText + " " + token.pos_ 
		
	return posText

def identifyMostCommonGrams(text, N, X):
	mostFrequentGrams = np.empty(X)

	amountOfNGrams = len(text.split()) - (N-1)
	gramArray = ['','']
	individualWordsList = text.split()
	gramWordsList = []
	for i in range(amountOfNGrams):
		gramWordsList.append(0)
	gramFrequencyList = []
	for i in range(amountOfNGrams):
		gramFrequencyList.append(0)

	#print(individualWordsList)

	for q in range(len(individualWordsList)-(N-1)):

		temp = ""

		for i in range(N):

			temp = temp + individualWordsList[i + q] + " "

		gramWordsList[q] = temp

	#print(gramWordsList)

	counter = collections.Counter(gramWordsList)
	return(str(counter.most_common(X)))

def main():


	for dirNo, dirName in enumerate(sorted(os.listdir(homeDir)), start = 1):
		#traverse directory
		#print("Directory " + dirName + ", number " + str(dirNo) + " recognized")
		#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
		for fileNo, fileName in enumerate(sorted(os.listdir(homeDir + dirName)), start = 1):
			#traverse file in directory
			#print("		File " + fileName + " from directory " + dirName + " recognized")
			#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
			if fileName.endswith('txt'):

				with open(homeDir + dirName + "/" + fileName, 'r', encoding = 'utf-8', errors = 'ignore') as f:

					print("Top 5 most common plaintext 3-grams in " + fileName + " of directory " + dirName + " are " + identifyMostCommonGrams(f.read(), 3, 5))

					print("Top 5 most common POS 3-grams in " + fileName + " of directory " + dirName + " are " + identifyMostCommonGrams(convertToPOS(f.read()), 3, 5))

			elif fileName.endswith('docx'):

				currentFile = docx2txt.process(homeDir + dirName + "/" + fileName)

				print("Top 5 most common plaintext 3-grams in " + fileName + " of directory " + dirName + " are " + identifyMostCommonGrams(currentFile, 3, 5))

				print("Top 5 most common POS 3-grams in " + fileName + " of directory " + dirName + " are " + identifyMostCommonGrams(convertToPOS(currentFile), 3, 5))

			else:
				print("invalid doctype!")




	

if __name__ == '__main__':

	print("initialized")

	main()

print("completed")
# Out:
# initialized
# invalid doctype!
# invalid doctype!
# invalid doctype!
# Top 5 most common plaintext 3-grams in 0.docx of directory 1 are [('plants will be ', 5), ('Martian Growth Systems ', 4), ('will be used. ', 4), ('the long term ', 3), ('long-lived and short-lived ', 3)]
# Top 5 most common POS 3-grams in 0.docx of directory 1 are [('PROPN PROPN PROPN ', 27), ('NOUN NOUN NOUN ', 26), ('DET ADJ NOUN ', 24), ('ADJ NOUN NOUN ', 23), ('NOUN VERB AUX ', 23)]
# Top 5 most common plaintext 3-grams in 1.docx of directory 1 are [('will have to ', 7), ('will be located ', 4), ('be located on ', 4), ('located on Malapert ', 4), ('on Malapert Mountain ', 4)]
# Top 5 most common POS 3-grams in 1.docx of directory 1 are [('ADP DET NOUN ', 28), ('NOUN ADP NOUN ', 27), ('DET NOUN ADP ', 24), ('NOUN ADP DET ', 21), ('NOUN VERB AUX ', 14)]
# Top 5 most common plaintext 3-grams in 2.docx of directory 1 are [('Applied Physics Laboratory, ', 10), ('(Johns Hopkins University ', 9), ('Hopkins University Applied ', 9), ('University Applied Physics ', 9), ('Retrieved January 25, ', 9)]
# Top 5 most common POS 3-grams in 2.docx of directory 1 are [('PROPN PROPN PROPN ', 132), ('DET NOUN ADP ', 29), ('ADP DET NOUN ', 26), ('DET ADJ NOUN ', 23), ('NOUN ADP DET ', 22)]
# Top 5 most common plaintext 3-grams in 3.docx of directory 1 are [('(Lockheed Martin, 2012). ', 7), ('can lead to ', 6), ('will have to ', 4), ('mental decay, and ', 3), ('is the most ', 3)]
# Top 5 most common POS 3-grams in 3.docx of directory 1 are [('NOUN ADP NOUN ', 39), ('NOUN CCONJ NOUN ', 34), ('NOUN NOUN VERB ', 28), ('NOUN VERB VERB ', 27), ('ADP NOUN NOUN ', 26)]
# Top 5 most common plaintext 3-grams in 4.docx of directory 1 are [('Mars Rover 2022 ', 20), ('Rover 2022 will ', 6), ('alpha particle X-ray ', 5), ('will land in ', 5), ('land in the ', 5)]
# Top 5 most common POS 3-grams in 4.docx of directory 1 are [('DET ADJ NOUN ', 43), ('PROPN PROPN PROPN ', 35), ('PROPN PROPN NUM ', 30), ('ADJ NOUN ADP ', 29), ('ADP DET NOUN ', 25)]
# Top 5 most common plaintext 3-grams in 5.docx of directory 1 are [('(University of Arizona ', 5), ('of Arizona Department ', 5), ('Arizona Department of ', 5), ('Department of Planetary ', 5), ('of Planetary Sciences, ', 5)]
# Top 5 most common POS 3-grams in 5.docx of directory 1 are [('PROPN PROPN PROPN ', 47), ('NOUN NOUN NOUN ', 41), ('ADP DET NOUN ', 41), ('DET ADJ NOUN ', 41), ('DET NOUN ADP ', 37)]
# Top 5 most common plaintext 3-grams in 7.docx of directory 1 are [('Guided Robotically Assisted ', 5), ('Robotically Assisted Space ', 5), ('Assisted Space glove ', 5), ('The Guided Robotically ', 4), ('Space glove aPparatus ', 4)]
# Top 5 most common POS 3-grams in 7.docx of directory 1 are [('PROPN PROPN PROPN ', 62), ('VERB DET NOUN ', 34), ('ADP DET NOUN ', 34), ('NOUN ADP DET ', 22), ('DET NOUN ADP ', 20)]
# Top 5 most common plaintext 3-grams in 0.txt of directory 2 are [('at the base ', 24), ('* ROMULUS BASE: ', 17), ('the production of ', 16), ('with mission control ', 14), ('the base site ', 14)]
# Top 5 most common POS 3-grams in 0.txt of directory 2 are []
# Top 5 most common plaintext 3-grams in 1.txt of directory 2 are [('Aeronautics and Space ', 5), ('and Space Administration ', 5), ('National Aeronautics and ', 4), ('the International Space ', 4), ('Sidereal Snooze is ', 3)]
# Top 5 most common POS 3-grams in 1.txt of directory 2 are []
# Top 5 most common plaintext 3-grams in 2.txt of directory 2 are [('the solid rocket ', 15), ('space shuttle Challenger ', 14), ('(“Engineering ethics,” n.d.). ', 13), ('the space shuttle ', 12), ('the NSPE Code ', 7)]
# Top 5 most common POS 3-grams in 2.txt of directory 2 are []
# Top 5 most common plaintext 3-grams in 3.txt of directory 2 are [('radiation, microgravity, and ', 5), ('as well as ', 4), ('is vital to ', 4), ('Space radiation, microgravity, ', 4), ('exposure to radiation ', 4)]
# Top 5 most common POS 3-grams in 3.txt of directory 2 are []
# Top 5 most common plaintext 3-grams in 4.txt of directory 2 are [('the Solar Wind ', 14), ('Solar Wind Composition ', 12), ('the foil sheet ', 10), ('Wind Composition Experiment ', 9), ('this experiment will ', 6)]
# Top 5 most common POS 3-grams in 4.txt of directory 2 are []
# Top 5 most common plaintext 3-grams in 5.txt of directory 2 are [('Atmospheric Drag and ', 11), ('Drag and Radiation ', 11), ('and Radiation Inquiry ', 10), ('the Atmospheric Drag ', 8), ('low Earth orbit ', 6)]
# Top 5 most common POS 3-grams in 5.txt of directory 2 are []
# Top 5 most common plaintext 3-grams in 6.txt of directory 2 are [('of the base ', 12), ('on the moon ', 9), ('the base and ', 6), ('of the lunar ', 6), ('the lunar crew ', 6)]
# Top 5 most common POS 3-grams in 6.txt of directory 2 are []
# Top 5 most common plaintext 3-grams in 7.txt of directory 2 are [('(NASA Science, n.d.). ', 6), ('as well as ', 5), ('the Mars Exploration ', 5), ('Earth and Mars ', 5), ('robotic surface exploration ', 5)]
# Top 5 most common POS 3-grams in 7.txt of directory 2 are []
# Top 5 most common plaintext 3-grams in 11.txt of directory 3 are [('was able to ', 5), ('a good example ', 4), ('what to do ', 3), ('the best way ', 2), ('best way to ', 2)]
# Top 5 most common POS 3-grams in 11.txt of directory 3 are []
# Top 5 most common plaintext 3-grams in 12.txt of directory 3 are [('to cling to ', 2), ('their power and ', 2), ('\ufeffThis article with ', 1), ('article with the ', 1), ('with the headline, ', 1)]
# Top 5 most common POS 3-grams in 12.txt of directory 3 are []
# Top 5 most common plaintext 3-grams in 13.txt of directory 3 are [('weaponization of artificial ', 7), ('the weaponization of ', 6), ('of artificial intelligence. ', 6), ('the development of ', 3), ('on the weaponization ', 3)]
# Top 5 most common POS 3-grams in 13.txt of directory 3 are []
# Top 5 most common plaintext 3-grams in 14.txt of directory 3 are [('the people around ', 3), ('the time they ', 3), ('time they have ', 2), ('pursue opportunities while ', 2), ('opportunities while they ', 2)]
# Top 5 most common POS 3-grams in 14.txt of directory 3 are []
# Top 5 most common plaintext 3-grams in 15.txt of directory 3 are [('I don’t think ', 2), ('sports should be ', 2), ('should be exclusionary. ', 2), ('want to play ', 2), ('to play the ', 2)]
# Top 5 most common POS 3-grams in 15.txt of directory 3 are []
# Top 5 most common plaintext 3-grams in 16.txt of directory 3 are [('I could get ', 2), ('is not unreasonable ', 2), ('not unreasonable to ', 2), ('cars on the ', 2), ('on the road ', 2)]
# Top 5 most common POS 3-grams in 16.txt of directory 3 are []
# Top 5 most common plaintext 3-grams in 17.txt of directory 3 are [('one of the ', 4), ('as well as ', 3), ('the South Atlantic ', 3), ('are full of ', 2), ('the Antarctic Treaty ', 2)]
# Top 5 most common POS 3-grams in 17.txt of directory 3 are []
# Top 5 most common plaintext 3-grams in 3.txt of directory 3 are [('reasoning is flawed ', 3), ('is flawed because ', 3), ('can learn from ', 2), ('learn from their ', 2), ('to succeed, and ', 2)]
# Top 5 most common POS 3-grams in 3.txt of directory 3 are []
# Top 5 most common plaintext 3-grams in 0.docx of directory 4 are [('Lunar Alpha Base ', 5), ('the south pole ', 4), ('a better understanding ', 3), ('better understanding of ', 3), ('would be the ', 3)]
# Top 5 most common POS 3-grams in 0.docx of directory 4 are [('PROPN PROPN PROPN ', 40), ('ADP DET NOUN ', 38), ('NOUN ADP DET ', 36), ('DET ADJ NOUN ', 35), ('ADJ NOUN ADP ', 28)]
# Top 5 most common plaintext 3-grams in 1.docx of directory 4 are [('Mars Geological Universal ', 6), ('Geological Universal Human ', 6), ('Universal Human Viability ', 6), ('Human Viability Base ', 6), ('in order to ', 5)]
# Top 5 most common POS 3-grams in 1.docx of directory 4 are [('ADP DET NOUN ', 110), ('PROPN PROPN PROPN ', 105), ('DET NOUN ADP ', 83), ('NOUN ADP DET ', 64), ('DET ADJ NOUN ', 59)]
# Top 5 most common plaintext 3-grams in 2.docx of directory 4 are [('Retrieved March 22, ', 7), ('March 22, 2020, ', 6), ('22, 2020, from ', 6), ('be used to ', 4), ('Human Viability on ', 3)]
# Top 5 most common POS 3-grams in 2.docx of directory 4 are [('ADP DET NOUN ', 38), ('DET ADJ NOUN ', 37), ('ADJ NOUN ADP ', 33), ('PROPN PROPN PROPN ', 31), ('NOUN ADP DET ', 28)]
# Top 5 most common plaintext 3-grams in 3.docx of directory 4 are [('Mars Robotic Surface ', 3), ('Robotic Surface Assessment ', 3), ('of the mission ', 3), ('mission will be ', 3), ('NESM (NASA, 2019). ', 3)]
# Top 5 most common POS 3-grams in 3.docx of directory 4 are [('PROPN PROPN PROPN ', 58), ('ADP DET NOUN ', 53), ('NOUN ADP DET ', 39), ('DET NOUN ADP ', 33), ('DET ADJ NOUN ', 32)]
# Top 5 most common plaintext 3-grams in 4.docx of directory 4 are [('(Demontis et al., ', 8), ('et al., 2017). ', 8), ('Retrieved March 21, ', 5), ('March 21, 2020, ', 5), ('21, 2020, from ', 5)]
# Top 5 most common POS 3-grams in 4.docx of directory 4 are [('PROPN PROPN PROPN ', 77), ('ADP DET NOUN ', 51), ('DET ADJ NOUN ', 49), ('NOUN ADP NOUN ', 43), ('ADJ NOUN ADP ', 35)]
# Top 5 most common plaintext 3-grams in 0.docx of directory 5 are [('the surface of ', 5), ('be able to ', 4), ('Drillmaster will be ', 3), ('of the rover ', 3), ('the rover will ', 3)]
# Top 5 most common POS 3-grams in 0.docx of directory 5 are [('ADP DET NOUN ', 48), ('NOUN ADP DET ', 33), ('DET NOUN ADP ', 32), ('DET NOUN VERB ', 25), ('NOUN ADP PROPN ', 22)]
# Top 5 most common plaintext 3-grams in 1.docx of directory 5 are [('on the moon ', 6), ('will be able ', 5), ('be able to ', 5), ('as well as ', 5), ('Retrieved February 9, ', 5)]
# Top 5 most common POS 3-grams in 1.docx of directory 5 are [('ADP DET NOUN ', 68), ('DET ADJ NOUN ', 56), ('NOUN ADP DET ', 52), ('NOUN CCONJ NOUN ', 33), ('NOUN PART VERB ', 32)]
# Top 5 most common plaintext 3-grams in 2.docx of directory 5 are [('Retrieved March 8, ', 7), ('March 8, 2020, ', 7), ('8, 2020, from ', 7), ('that can be ', 5), ('the carbon dioxide ', 4)]
# Top 5 most common POS 3-grams in 2.docx of directory 5 are [('NOUN ADP NOUN ', 43), ('ADP DET NOUN ', 36), ('NOUN PART VERB ', 32), ('VERB DET NOUN ', 32), ('NOUN ADP DET ', 30)]
# Top 5 most common plaintext 3-grams in 3.docx of directory 5 are [('Retrieved January 25, ', 8), ('January 25, 2020, ', 8), ('25, 2020, from ', 8), ('volcanic eruptions and ', 5), ('climate change and ', 4)]
# Top 5 most common POS 3-grams in 3.docx of directory 5 are [('ADP DET NOUN ', 39), ('PROPN PROPN PROPN ', 38), ('NOUN ADP DET ', 33), ('NOUN ADP NOUN ', 31), ('DET NOUN ADP ', 31)]
# Top 5 most common plaintext 3-grams in 4.docx of directory 5 are [('Retrieved January 12, ', 10), ('January 12, 2020, ', 10), ('12, 2020, from ', 10), ('External Robotic Arm ', 6), ('External Robotic Arms ', 4)]
# Top 5 most common POS 3-grams in 4.docx of directory 5 are [('PROPN PROPN PROPN ', 48), ('NOUN ADP DET ', 45), ('ADP DET NOUN ', 40), ('DET NOUN ADP ', 31), ('DET ADJ NOUN ', 23)]
# Top 5 most common plaintext 3-grams in 5.docx of directory 5 are [('Code of Ethics ', 5), ('of Ethics for ', 5), ('the Code of ', 4), ('Space Shuttle Challenger ', 4), ('Challenger Space Shuttle ', 3)]
# Top 5 most common POS 3-grams in 5.docx of directory 5 are [('ADP DET NOUN ', 39), ('NOUN ADP DET ', 36), ('DET NOUN ADP ', 32), ('PROPN PROPN PROPN ', 31), ('ADP DET PROPN ', 20)]
# Top 5 most common plaintext 3-grams in 0.txt of directory 6 are [('the ISS and ', 3), ('of the ISS. ', 3), ('will be able ', 3), ('be able to ', 3), ('the safety of ', 3)]
# Top 5 most common POS 3-grams in 0.txt of directory 6 are []
# Top 5 most common plaintext 3-grams in 1.docx of directory 6 are [('SLS Block 2 ', 6), ('Block 2 Cargo ', 6), ('Ares I, II, ', 6), ('I, II, and ', 6), ('the Hohmann Transfer ', 6)]
# Top 5 most common POS 3-grams in 1.docx of directory 6 are [('DET ADJ NOUN ', 120), ('NOUN ADP DET ', 111), ('ADP DET NOUN ', 110), ('VERB DET NOUN ', 107), ('PROPN PROPN PROPN ', 96)]
# Top 5 most common plaintext 3-grams in 2.docx of directory 6 are [('STS-51L Case Study ', 4), ('Case Study Report ', 4), ('Code of Ethics ', 4), ('The Challenger Disaster ', 3), ('(Code of Ethics, ', 3)]
# Top 5 most common POS 3-grams in 2.docx of directory 6 are [('PROPN PROPN PROPN ', 60), ('VERB DET NOUN ', 38), ('DET ADJ NOUN ', 36), ('ADP DET NOUN ', 34), ('DET NOUN ADP ', 27)]
# Top 5 most common plaintext 3-grams in 3.docx of directory 6 are [('the ice cap ', 7), ('a better understanding ', 5), ('better understanding of ', 5), ('the composition of ', 4), ('composition of the ', 4)]
# Top 5 most common POS 3-grams in 3.docx of directory 6 are [('DET ADJ NOUN ', 62), ('ADP DET NOUN ', 57), ('DET NOUN ADP ', 56), ('NOUN ADP DET ', 54), ('PROPN PROPN PROPN ', 46)]
# Top 5 most common plaintext 3-grams in 4.docx of directory 6 are [('Advanced Closed Loop ', 4), ('U.S. Army Natick ', 4), ('Army Natick Soldier ', 4), ('Natick Soldier Research, ', 4), ('Soldier Research, Development ', 4)]
# Top 5 most common POS 3-grams in 4.docx of directory 6 are [('ADP DET NOUN ', 83), ('NOUN ADP DET ', 66), ('DET ADJ NOUN ', 66), ('PROPN PROPN PROPN ', 58), ('VERB DET NOUN ', 55)]
# Top 5 most common plaintext 3-grams in 5.docx of directory 6 are [('will have to ', 6), ('will be the ', 5), ('the greenhouse will ', 5), ('experiment will be ', 4), ('life support systems ', 4)]
# Top 5 most common POS 3-grams in 5.docx of directory 6 are [('DET ADJ NOUN ', 60), ('ADP DET NOUN ', 59), ('VERB DET NOUN ', 51), ('NOUN PART VERB ', 48), ('ADJ NOUN ADP ', 44)]
# Top 5 most common plaintext 3-grams in 6.docx of directory 6 are [('on the Moon ', 8), ('Project Artemis is ', 5), ('the Moon to ', 5), ('Artemis is a ', 4), ('at a time ', 4)]
# Top 5 most common POS 3-grams in 6.docx of directory 6 are [('DET ADJ NOUN ', 105), ('ADP DET NOUN ', 91), ('DET NOUN ADP ', 82), ('NOUN ADP DET ', 82), ('VERB DET NOUN ', 64)]
# Top 5 most common plaintext 3-grams in 7.docx of directory 6 are [('the asteroid belt ', 6), ('will be a ', 6), ('(Overview: Ceres, 2019). ', 5), ('in the asteroid ', 4), ('the asteroid belt. ', 4)]
# Top 5 most common POS 3-grams in 7.docx of directory 6 are [('DET ADJ NOUN ', 66), ('ADP DET NOUN ', 51), ('NOUN ADP DET ', 44), ('DET NOUN ADP ', 37), ('NOUN ADP NOUN ', 37)]
# Top 5 most common plaintext 3-grams in 0.txt of directory 7 are [('rover and the ', 7), ('on the Moon ', 6), ('the rover and ', 6), ('and the orbiter ', 6), ('to the Moon ', 5)]
# Top 5 most common POS 3-grams in 0.txt of directory 7 are []
# Top 5 most common plaintext 3-grams in 1.txt of directory 7 are [('at Mars for ', 3), ('to go to ', 3), ('the human race ', 3), ('Due to the ', 3), ('the composition of ', 3)]
# Top 5 most common POS 3-grams in 1.txt of directory 7 are []
# Top 5 most common plaintext 3-grams in 2.txt of directory 7 are [('of this mission ', 6), ('mission is to ', 5), ('for this mission ', 5), ('Mars Rover: Athena ', 4), ('the Mars 2020 ', 4)]
# Top 5 most common POS 3-grams in 2.txt of directory 7 are []
# Top 5 most common plaintext 3-grams in 3.txt of directory 7 are [('the handheld LIDAR ', 7), ('the software program ', 6), ('of the ISS ', 5), ('set of equipment ', 5), ('and Software to ', 4)]
# Top 5 most common POS 3-grams in 3.txt of directory 7 are []
# Top 5 most common plaintext 3-grams in 4.txt of directory 7 are [('the lunar base ', 8), ('a lunar base ', 6), ('on the Moon. ', 6), ('on the Moon ', 6), ('there will be ', 5)]
# Top 5 most common POS 3-grams in 4.txt of directory 7 are []
# Top 5 most common plaintext 3-grams in 0.txt of directory 8 are [('Retrieved February 17, ', 7), ('February 17, 2020, ', 7), ('17, 2020, from ', 7), ('for a Mars ', 5), ('a Mars base ', 4)]
# Top 5 most common POS 3-grams in 0.txt of directory 8 are []
# Top 5 most common plaintext 3-grams in 1.txt of directory 8 are [('whether or not ', 6), ('Thiophene Bioticity Experiment ', 4), ('determine whether or ', 4), ('a team of ', 4), ('that the thiophenes ', 4)]
# Top 5 most common POS 3-grams in 1.txt of directory 8 are []
# Top 5 most common plaintext 3-grams in 2.txt of directory 8 are [('Retrieved March 6, ', 9), ('March 6, 2020, ', 9), ('6, 2020, from ', 9), ('due to the ', 3), ('to Mars from ', 3)]
# Top 5 most common POS 3-grams in 2.txt of directory 8 are []
# Top 5 most common plaintext 3-grams in 3.txt of directory 8 are [('Retrieved February 3, ', 11), ('February 3, 2020, ', 11), ('3, 2020, from ', 11), ('and Commercial Operations ', 4), ('Commercial Operations Module ', 4)]
# Top 5 most common POS 3-grams in 3.txt of directory 8 are []
# Top 5 most common plaintext 3-grams in 4.txt of directory 8 are [('Retrieved April 1, ', 15), ('April 1, 2020, ', 15), ('1, 2020, from ', 15), ('the MAREST base ', 7), ('of the MAREST ', 6)]
# Top 5 most common POS 3-grams in 4.txt of directory 8 are []
# completed

# %%
print(identifyMostCommonGrams("hi hi hi hi hi i like to i like to i like", 3, 2))
# Out:
# [('hi hi hi ', 3), ('i like to ', 2)]
